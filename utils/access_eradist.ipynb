# %% [markdown]
# This will kill your notebook to make sure we are setting up everyting in a clean way. Execute the cell if you are on colab. Then execute the one below.

# %%
import os
import sys

if 'google.colab' in sys.modules:
  os.kill(os.getpid(), 9)

# %%
import sys
import os

if 'google.colab' in sys.modules:
    # Check if the repository is already cloned
    # %cd /content/
    if not os.path.exists('/content/risk-analysis'):
        # !git clone https://github.com/theresa-hefele/risk-analysis.git
    # %cd risk-analysis
    # !git submodule init
    # !git submodule update
    
    # Add the Classes directory to Python path, all the files in Classes/ are now accessible
    classes_path = '/content/risk-analysis/Overview/ERADist/ERA_Distribution_Classes_Python/Classes/'

    sys.path.insert(0, classes_path)
    
    # Change directory for the notebook if there is data we need in the current weeks directory.
    # !ls
else:
    # If you are running locally, you need to copy the Classes directory to the current working directory
    print("Not running in Google Colab environment.")

# !pip install numpy
# !pip install scipy

# %%
from ERADist import ERADist

frechet = ERADist(name='Frechet', opt='Mom', val=[40, 20])
